# %%
# =============================================================================
# DYNAMIC FACTOR MODEL (DFM) -- Monthly IVAE Nowcasting (El Salvador)
# =============================================================================
# Implementation using statsmodels.tsa.statespace.dynamic_factor
# This replaces nowcastDFM (R) which was designed for quarterly targets.
#
# Why statsmodels instead of nowcastDFM:
#   - nowcastDFM was designed for quarterly targets with monthly indicators
#   - statsmodels handles monthly targets natively and efficiently
#   - Kalman filter runs once over full sample (not per prediction call)
#   - Based on the same Banbura & Modugno (2014) framework
#
# Model:
#   y_t = Lambda * f_t + e_t    (observation equation)
#   f_t = A * f_{t-1} + u_t     (state equation)
#
# References:
#   Banbura & Modugno (2014). JAE.
#   Stock & Watson (2002). JASA.
# =============================================================================

# -- Setup --------------------------------------------------------------------
import os
os.chdir("/Users/gabrielaaquino/Desktop/real-time-gdp-nowcasting-sv/Models")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.statespace.dynamic_factor import DynamicFactor
from sklearn.preprocessing import StandardScaler

from utils import (
    CONFIG, load_data, gen_lagged_data,
    compute_metrics, get_monthly_test_dates, print_performance_table,
)

plt.rcParams["figure.figsize"] = [12, 5]

# =============================================================================
# 1. CONFIGURATION
# =============================================================================

TARGET    = CONFIG["target_variable"]   # IVAE_TOT
LAGS_USE  = CONFIG["lags"]              # [-2, -1, 0]
N_FACTORS = 4                           # one per economic block

# Parsimonious variable selection -- one representative per subcategory
# Following Stock & Watson (2002) and Bai & Ng (2002)
VARS_DFM = [
    "IVAE_TOT",                          # TARGET
    # block_s: real activity
    "IVAE_AG", "IVAE_IN", "IVAE_CO", "IVAE_CT", "IVAE_AF",
    "IPI", "PRO_ENER", "CON_ENER", "CON_APA_CEM",
    "ISSS_SEC", "ISSS_TER", "CE_TOT_VV",
    # block_r: external sector
    "EXP_IM", "EXP_CP", "EXP_MO",
    "IMP_IM", "IMP_D_IM", "IMP_D_BN",
    "REM", "IPI_US", "UNEM_US", "EFFR_US",
    # block_l: fiscal + financial
    "INGT_IVA", "INGT_ISR", "GPC", "GIP", "BFG",
    "M3", "CTC", "CCO", "CPI",
    "TIP_30", "TIP_180", "TPR1",
    # quarterly anchors
    "GDP", "GDP_IN", "GDP_CO",
]

print("=" * 55)
print("  DFM -- Monthly IVAE Nowcasting (Python)")
print("=" * 55)
print(f"Target    : {TARGET}")
print(f"Vintages  : {LAGS_USE}")
print(f"Factors   : {N_FACTORS}")
print(f"Variables : {len(VARS_DFM)}")

# =============================================================================
# 2. LOAD DATA
# =============================================================================

data, metadata = load_data()

available_vars = [v for v in VARS_DFM if v in data.columns]
data_dfm = data[["date"] + available_vars].copy()

print(f"\nVariables available : {len(available_vars)}")
print(f"Date range          : {data_dfm.date.min().date()} -> {data_dfm.date.max().date()}")

# =============================================================================
# 3. TRAINING DATA -- PRE-CRISIS
# =============================================================================

train_end = pd.Timestamp(CONFIG["window_1"]["start_date"]) - pd.DateOffset(months=1)

train_data = data_dfm.loc[
    (data_dfm.date >= pd.Timestamp(CONFIG["train_start_date"])) &
    (data_dfm.date <= train_end),
    available_vars
].copy().reset_index(drop=True)

print(f"\nTraining obs : {len(train_data)}")
print(f"Training end : {train_end.date()}")

# =============================================================================
# 4. ESTIMATE DFM ONCE ON TRAINING DATA
# =============================================================================

print("\n>>> Estimating DFM on pre-crisis training data...")

# Drop columns with >80% missing
missing_pct = train_data.isna().mean()
dfm_cols    = missing_pct[missing_pct < 0.8].index.tolist()
print(f"  Variables after missing filter: {len(dfm_cols)}")

# Standardize -- DFM requires standardized inputs
scaler     = StandardScaler()
X_train    = train_data[dfm_cols].fillna(train_data[dfm_cols].mean())
X_scaled   = pd.DataFrame(scaler.fit_transform(X_train), columns=dfm_cols)

# Fit DFM
model = DynamicFactor(
    X_scaled,
    k_factors      = N_FACTORS,
    factor_order   = 1,
    error_order    = 0,
    error_cov_type = "diagonal"
)

dfm_result = model.fit(
    method  = "lbfgs",
    maxiter = 200,
    disp    = True,
)
print(f"  Log-likelihood : {dfm_result.llf:.4f}")
print(f"  AIC            : {dfm_result.aic:.4f}")

# =============================================================================
# 5. PREDICTION FUNCTION
# =============================================================================

def predict_dfm_monthly(data_full, metadata, target_date, lag):
    """
    Predict IVAE_TOT for target_date using pre-estimated DFM.

    1. Generate ragged-edge dataset for this vintage
    2. Standardize using training scaler
    3. Apply Kalman smoother
    4. Extract and rescale prediction for target month
    """
    lagged = gen_lagged_data(metadata, data_full, target_date, lag)

    # Keep only DFM variables
    X_pred = lagged[[c for c in dfm_cols if c in lagged.columns]].copy()

    # Mask target to prevent leakage
    if TARGET in X_pred.columns:
        X_pred[TARGET] = np.nan

    # Fill NAs with training means for standardization
    X_filled = X_pred.fillna(X_train[dfm_cols].mean() if dfm_cols[0] in X_pred.columns
                             else X_pred.mean())

    # Align to training column order
    for c in dfm_cols:
        if c not in X_filled.columns:
            X_filled[c] = 0.0
    X_filled = X_filled[dfm_cols]

    # Standardize
    X_new_scaled = pd.DataFrame(
        scaler.transform(X_filled),
        columns = dfm_cols
    )

    try:
        # Apply model to new data
        pred_result   = dfm_result.apply(X_new_scaled)
        fitted_scaled = pred_result.fittedvalues

        if TARGET not in fitted_scaled.columns:
            return np.nan

        pred_scaled = float(fitted_scaled[TARGET].iloc[-1])

        # Rescale to original units
        idx           = dfm_cols.index(TARGET)
        pred_original = pred_scaled * scaler.scale_[idx] + scaler.mean_[idx]

        return float(pred_original)

    except Exception:
        return np.nan

# =============================================================================
# 6. NOWCAST LOOP -- TWO WINDOWS
# =============================================================================

def run_window(window_cfg, window_label):
    print(f"\n{'='*55}\n  Window: {window_label}\n{'='*55}")

    dates_df     = get_monthly_test_dates(window=window_cfg)
    all_months   = dates_df["date"].tolist()
    pred_dict    = {lag: {} for lag in LAGS_USE}
    actuals_dict = {}

    for month in all_months:
        date_str   = str(month.date())
        actual_row = data.loc[data.date == month, TARGET]

        if actual_row.empty or actual_row.isna().all():
            continue

        actuals_dict[date_str] = float(actual_row.values[0])

        for lag in LAGS_USE:
            pred_dict[lag][date_str] = predict_dfm_monthly(
                data, metadata, date_str, lag
            )

        print(f"  {date_str}: "
              f"actual={actuals_dict[date_str]*100:+.2f}%  "
              f"lag-2={pred_dict[-2].get(date_str, np.nan)*100:+.2f}%  "
              f"lag-1={pred_dict[-1].get(date_str, np.nan)*100:+.2f}%  "
              f"lag 0={pred_dict[0].get(date_str, np.nan)*100:+.2f}%")

    # Metrics
    rows = []
    for lag in LAGS_USE:
        common = [d for d in actuals_dict
                  if d in pred_dict[lag] and not np.isnan(pred_dict[lag][d])]
        if not common:
            continue
        a = np.array([actuals_dict[d]   for d in common])
        f = np.array([pred_dict[lag][d] for d in common])
        m = compute_metrics(a, f, label=str(lag))
        m["Vintage"] = lag
        rows.append(m)

    perf = pd.DataFrame(rows)[["Vintage", "RMSE", "MAE", "R2", "n"]]
    print_performance_table(perf.round(4), f"DFM -- {window_label}")
    return perf, pred_dict, actuals_dict


print("\n>>> Running Window 1: Crisis (COVID-19)")
perf_w1, preds_w1, actuals_w1 = run_window(CONFIG["window_1"], "Crisis (COVID-19)")

print("\n>>> Running Window 2: Post-Pandemic")
perf_w2, preds_w2, actuals_w2 = run_window(CONFIG["window_2"], "Post-Pandemic Normalisation")

# =============================================================================
# 7. COMBINED PERFORMANCE TABLE
# =============================================================================

perf_w1["Window"] = "Crisis"
perf_w2["Window"] = "Post-Pandemic"
combined = pd.concat([perf_w1, perf_w2], ignore_index=True)
combined["Model"] = "DFM"

print("\n-- Combined Performance --")
print(combined[["Model", "Window", "Vintage", "RMSE", "MAE", "R2", "n"]]
      .to_string(index=False))

# =============================================================================
# 8. FACTOR LOADINGS
# =============================================================================

print("\n--- Factor Loadings (top 5 per factor) ---")
try:
    loadings = pd.DataFrame(
        dfm_result.loadings,
        index   = dfm_cols,
        columns = [f"F{i+1}" for i in range(N_FACTORS)]
    )
    for col in loadings.columns:
        top5 = loadings[col].abs().nlargest(5)
        print(f"\n  {col}:")
        for var, _ in top5.items():
            print(f"    {var:20}: {loadings.loc[var, col]:+.4f}")
except Exception:
    print("  Loadings not available.")

# =============================================================================
# 9. VISUALIZATIONS
# =============================================================================

def plot_window(preds, actuals_dict, window_label):
    dates   = sorted(actuals_dict.keys())
    dt      = [pd.Timestamp(d) for d in dates]
    actual  = [actuals_dict[d] * 100 for d in dates]
    pred_0  = [preds[0].get(d,  np.nan) * 100 for d in dates]
    pred_m1 = [preds[-1].get(d, np.nan) * 100 for d in dates]
    pred_m2 = [preds[-2].get(d, np.nan) * 100 for d in dates]

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(13, 9))

    ax1.plot(dt, actual,  color="black",   lw=1.8, label="Actual IVAE m-o-m")
    ax1.plot(dt, pred_0,  color="#2166ac", lw=1.2, ls="--", label="Nowcast (lag 0)")
    ax1.plot(dt, pred_m1, color="#f46d43", lw=1.0, ls=":",  label="lag -1", alpha=0.85)
    ax1.plot(dt, pred_m2, color="#abdda4", lw=1.0, ls="-.", label="lag -2", alpha=0.85)
    ax1.axhline(0, color="gray", lw=0.6, ls="--")
    ax1.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha="right")
    ax1.set_title(f"DFM | {window_label}", fontsize=12, fontweight="bold")
    ax1.set_ylabel("IVAE m-o-m (%)")
    ax1.legend(fontsize=9)
    ax1.grid(True, alpha=0.3)

    valid  = [(t, a, p) for t, a, p in zip(dt, actual, pred_0) if not np.isnan(p)]
    err_dt = [v[0] for v in valid]
    errors = [v[1] - v[2] for v in valid]
    colors_bar = ["#d73027" if e < 0 else "#4dac26" for e in errors]
    ax2.bar(err_dt, errors, color=colors_bar, width=20, alpha=0.85)
    ax2.axhline(0, color="black", lw=0.8)
    ax2.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha="right")
    ax2.set_title("Forecast Errors -- Actual minus Predicted (lag 0)", fontsize=11)
    ax2.set_ylabel("Error (pp)")
    ax2.grid(True, alpha=0.3)

    plt.suptitle(f"DFM | El Salvador IVAE Nowcasting | {window_label}",
                 fontsize=13, fontweight="bold")
    plt.tight_layout()
    plt.show()


plot_window(preds_w1, actuals_w1, "Crisis (COVID-19)")
plot_window(preds_w2, actuals_w2, "Post-Pandemic Normalisation")

# =============================================================================
# 10. SAVE RESULTS
# =============================================================================

def build_output(preds, actuals_dict, window_name):
    dates = sorted(actuals_dict.keys())
    return pd.DataFrame({
        "date"        : dates,
        "actual"      : [actuals_dict[d]          for d in dates],
        "pred_lag_m2" : [preds[-2].get(d, np.nan) for d in dates],
        "pred_lag_m1" : [preds[-1].get(d, np.nan) for d in dates],
        "pred_lag_0"  : [preds[0].get(d,  np.nan) for d in dates],
        "model"       : "DFM",
        "window"      : window_name,
    })

results = pd.concat([
    build_output(preds_w1, actuals_w1, "Crisis"),
    build_output(preds_w2, actuals_w2, "Post-Pandemic"),
], ignore_index=True)

os.makedirs("outputs", exist_ok=True)
results.to_csv("outputs/dfm_predictions.csv", index=False)
combined.to_csv("outputs/dfm_performance.csv", index=False)

print(f"\nDFM complete.")
print(f"Predictions : outputs/dfm_predictions.csv ({len(results)} rows)")
print(f"Performance : outputs/dfm_performance.csv")
print(f"\nNext: Ridge regression")
# Out:
# =======================================================
#   DFM -- Monthly IVAE Nowcasting (Python)
# =======================================================
# Target    : IVAE_TOT
# Vintages  : [-2, -1, 0]
# Factors   : 4
# Variables : 38
# Data loaded  : 237 rows x 123 variables
# Date range   : 2005-01-01 -> 2024-06-01
# Target (IVAE): 233 monthly observations
#
# Variables available : 38
# Date range          : 2005-01-01 -> 2024-06-01
#
# Training obs : 170
# Training end : 2019-02-01
#
# >>> Estimating DFM on pre-crisis training data...
#   Variables after missing filter: 38
#   Log-likelihood : -7730.0190
#   AIC            : 15872.0380
#
# >>> Running Window 1: Crisis (COVID-19)
#
# =======================================================
#   Window: Crisis (COVID-19)
# =======================================================
# Window  : Crisis (COVID-19)
# Months  : 28 (10 quarters)
# Period  : 2019-03-01 -> 2021-06-01
#   2019-03-01: actual=+0.33%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-04-01: actual=+0.86%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-05-01: actual=-1.29%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-06-01: actual=+0.97%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-07-01: actual=+0.05%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-08-01: actual=+0.14%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-09-01: actual=+0.39%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-10-01: actual=-0.35%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-11-01: actual=+1.02%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-12-01: actual=+0.00%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-01-01: actual=-0.93%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-02-01: actual=+0.50%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-03-01: actual=-7.85%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-04-01: actual=-13.22%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-05-01: actual=-3.38%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-06-01: actual=+6.94%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-07-01: actual=+5.41%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-08-01: actual=+5.10%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-09-01: actual=+4.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-10-01: actual=+0.78%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-11-01: actual=+0.49%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-12-01: actual=+1.62%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-01-01: actual=+0.45%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-02-01: actual=+0.61%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-03-01: actual=+0.36%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-04-01: actual=+0.74%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-05-01: actual=-0.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-06-01: actual=+1.08%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#
# ==========================================================
#   DFM -- Crisis (COVID-19) -- Performance by Vintage
# ==========================================================
#  Vintage   RMSE    MAE      R2  n
#       -2 0.0368 0.0204 -0.0001 28
#       -1 0.0368 0.0204 -0.0001 28
#        0 0.0368 0.0204  0.0001 28
#
# Vintage key:
#   -2 -> Month 1 of quarter  (least information)
#   -1 -> Month 2 of quarter
#    0 -> Month 3 / quarter-end  (most information)
#
# >>> Running Window 2: Post-Pandemic
#
# =======================================================
#   Window: Post-Pandemic Normalisation
# =======================================================
# Window  : Post-Pandemic Normalisation
# Months  : 34 (12 quarters)
# Period  : 2021-09-01 -> 2024-06-01
#   2021-09-01: actual=+0.50%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-10-01: actual=+0.18%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-11-01: actual=+0.31%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-12-01: actual=-0.75%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-01-01: actual=+0.68%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-02-01: actual=+0.36%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-03-01: actual=+0.54%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-04-01: actual=-0.48%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-05-01: actual=+1.70%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-06-01: actual=-0.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-07-01: actual=+0.30%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-08-01: actual=+0.81%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-09-01: actual=-0.38%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-10-01: actual=+0.82%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-11-01: actual=-0.96%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-12-01: actual=-0.34%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-01-01: actual=+1.45%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-02-01: actual=-0.49%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-03-01: actual=+1.45%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-04-01: actual=+0.06%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-05-01: actual=+1.27%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-06-01: actual=+0.39%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-07-01: actual=-0.52%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-08-01: actual=-1.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-09-01: actual=+0.15%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-10-01: actual=-0.13%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-11-01: actual=+3.15%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2023-12-01: actual=-1.43%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2024-01-01: actual=+1.84%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2024-02-01: actual=-1.96%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2024-03-01: actual=-0.06%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2024-04-01: actual=+0.35%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2024-05-01: actual=+1.46%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#   2024-06-01: actual=-2.61%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.20%
#
# ====================================================================
#   DFM -- Post-Pandemic Normalisation -- Performance by Vintage
# ====================================================================
#  Vintage   RMSE    MAE      R2  n
#       -2 0.0112 0.0084 -0.0005 34
#       -1 0.0112 0.0084 -0.0005 34
#        0 0.0112 0.0084  0.0002 34
#
# Vintage key:
#   -2 -> Month 1 of quarter  (least information)
#   -1 -> Month 2 of quarter
#    0 -> Month 3 / quarter-end  (most information)
#
# -- Combined Performance --
# Model        Window  Vintage     RMSE      MAE        R2  n
#   DFM        Crisis       -2 0.036832 0.020406 -0.000101 28
#   DFM        Crisis       -1 0.036832 0.020406 -0.000101 28
#   DFM        Crisis        0 0.036828 0.020398  0.000109 28
#   DFM Post-Pandemic       -2 0.011195 0.008371 -0.000459 34
#   DFM Post-Pandemic       -1 0.011195 0.008371 -0.000459 34
#   DFM Post-Pandemic        0 0.011191 0.008362  0.000246 34
#
# --- Factor Loadings (top 5 per factor) ---
#   Loadings not available.
# DFM complete.
# Predictions : outputs/dfm_predictions.csv (62 rows)
# Performance : outputs/dfm_performance.csv
#
# Next: Ridge regression

# %%
# Corre esto en Jupyter primero
import statsmodels
print(statsmodels.__version__)

from statsmodels.tsa.statespace.dynamic_factor_mq import DynamicFactorMQ
print("DynamicFactorMQ disponible")
# Out:
# 0.14.6
# DynamicFactorMQ disponible

# %%
# =============================================================================
# DYNAMIC FACTOR MODEL (DFM) -- Monthly IVAE Nowcasting (El Salvador)
# =============================================================================
# Uses DynamicFactorMQ (statsmodels 0.13+) with EM algorithm.
# Target: IVAE_TOT m-o-m growth rate (monthly).
# Comparable to all other models (ARMA, Ridge, etc.)
# =============================================================================

# -- Setup --------------------------------------------------------------------
import os
os.chdir("/Users/gabrielaaquino/Desktop/real-time-gdp-nowcasting-sv/Models")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.statespace.dynamic_factor_mq import DynamicFactorMQ
from sklearn.preprocessing import StandardScaler

from utils import (
    CONFIG, load_data, gen_lagged_data,
    compute_metrics, get_monthly_test_dates, print_performance_table,
)

plt.rcParams["figure.figsize"] = [12, 5]

# =============================================================================
# 1. CONFIGURATION
# =============================================================================

TARGET    = CONFIG["target_variable"]   # IVAE_TOT
LAGS_USE  = CONFIG["lags"]              # [-2, -1, 0]
N_FACTORS = 4

VARS_DFM = [
    "IVAE_TOT",
    # block_s: real activity
    "IVAE_AG", "IVAE_IN", "IVAE_CO", "IVAE_CT", "IVAE_AF",
    "IPI", "PRO_ENER", "CON_ENER", "CON_APA_CEM",
    "ISSS_SEC", "ISSS_TER", "CE_TOT_VV",
    # block_r: external sector
    "EXP_IM", "EXP_CP", "EXP_MO",
    "IMP_IM", "IMP_D_IM", "IMP_D_BN",
    "REM", "IPI_US", "UNEM_US", "EFFR_US",
    # block_l: fiscal + financial
    "INGT_IVA", "INGT_ISR", "GPC", "GIP", "BFG",
    "M3", "CTC", "CCO", "CPI",
    "TIP_30", "TIP_180", "TPR1",
    # quarterly anchors
    "GDP", "GDP_IN", "GDP_CO",
]

print("=" * 55)
print("  DFM -- Monthly IVAE Nowcasting (Python)")
print("=" * 55)
print(f"Target    : {TARGET}")
print(f"Vintages  : {LAGS_USE}")
print(f"Factors   : {N_FACTORS}")
print(f"Variables : {len(VARS_DFM)}")

# =============================================================================
# 2. LOAD DATA
# =============================================================================

data, metadata = load_data()

available_vars = [v for v in VARS_DFM if v in data.columns]
data_dfm = data[["date"] + available_vars].copy()

print(f"\nVariables available : {len(available_vars)}")

# =============================================================================
# 3. TRAINING DATA
# =============================================================================

train_end = pd.Timestamp(CONFIG["window_1"]["start_date"]) - pd.DateOffset(months=1)

train_data = data_dfm.loc[
    (data_dfm.date >= pd.Timestamp(CONFIG["train_start_date"])) &
    (data_dfm.date <= train_end),
    available_vars
].copy().reset_index(drop=True)

print(f"Training obs : {len(train_data)}")
print(f"Training end : {train_end.date()}")

# Drop columns with >80% missing
missing_pct = train_data.isna().mean()
dfm_cols    = missing_pct[missing_pct < 0.8].index.tolist()
print(f"Variables after missing filter: {len(dfm_cols)}")

# Standardize
scaler   = StandardScaler()
X_train  = train_data[dfm_cols].copy()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X_train.fillna(X_train.mean())),
    columns = dfm_cols
)

# =============================================================================
# 4. ESTIMATE DFM ONCE
# =============================================================================

print("\n>>> Estimating DFM...")

model = DynamicFactorMQ(
    X_scaled,
    factors           = N_FACTORS,
    factor_orders     = 1,
    idiosyncratic_ar1 = False,
)

dfm_result = model.fit(
    method  = "em",
    maxiter = 200,
    disp    = True,
)

print(f"Log-likelihood : {dfm_result.llf:.4f}")

# =============================================================================
# 5. DIAGNOSE PREDICTION METHOD
# =============================================================================
# Test which method works correctly for out-of-sample prediction

print("\n>>> Diagnosing prediction method...")

def get_test_X(target_date_str, lag_val):
    """Build standardized input for a given date and lag."""
    lagged = gen_lagged_data(metadata, data, target_date_str, lag_val)
    X_pred = lagged[[c for c in dfm_cols if c in lagged.columns]].copy()
    # Mask target
    if TARGET in X_pred.columns:
        X_pred[TARGET] = np.nan
    # Align columns
    for col in dfm_cols:
        if col not in X_pred.columns:
            X_pred[col] = np.nan
    X_pred = X_pred[dfm_cols]
    # Fill NAs with training means
    col_means = X_train.mean()
    for col in dfm_cols:
        X_pred[col] = X_pred[col].fillna(col_means.get(col, 0))
    # Standardize
    return pd.DataFrame(
        scaler.transform(X_pred),
        columns=dfm_cols
    )

# Test with one date
test_X = get_test_X("2019-06-01", 0)
target_col_idx = dfm_cols.index(TARGET) if TARGET in dfm_cols else 0

# Method 1: apply() + fittedvalues
try:
    app = dfm_result.apply(test_X, refit=False)
    val1 = float(app.fittedvalues[TARGET].iloc[-1])
    val1_rescaled = val1 * scaler.scale_[target_col_idx] + scaler.mean_[target_col_idx]
    print(f"  Method apply+fittedvalues: {val1_rescaled*100:.3f}%")
    USE_METHOD = "apply_fitted"
except Exception as e:
    print(f"  Method apply+fittedvalues FAILED: {e}")
    USE_METHOD = None

# Method 2: apply() + predicted_state
try:
    app2 = dfm_result.apply(test_X, refit=False)
    # Get the predicted observation from smoothed state
    smoothed = app2.smoothed_state  # shape: (n_states, T)
    # Observation = loadings @ factors (first N_FACTORS rows of state)
    factors_last = smoothed[:N_FACTORS, -1]
    # Get loadings matrix
    loadings = np.array(dfm_result.loadings)  # shape: (n_obs, n_factors)
    pred_scaled = float(loadings[target_col_idx] @ factors_last)
    pred_rescaled = pred_scaled * scaler.scale_[target_col_idx] + scaler.mean_[target_col_idx]
    print(f"  Method smoothed_state:     {pred_rescaled*100:.3f}%")
    if USE_METHOD is None:
        USE_METHOD = "smoothed_state"
except Exception as e:
    print(f"  Method smoothed_state FAILED: {e}")

print(f"  Using method: {USE_METHOD}")
print(f"  Actual IVAE 2019-06: {float(data.loc[data.date=='2019-06-01', TARGET].values[0])*100:.3f}%")

# =============================================================================
# 6. PREDICTION FUNCTION
# =============================================================================

# Reemplaza la funcion predict_dfm_monthly completa por esto:

def predict_dfm_monthly(data_full, metadata, target_date, lag):
    try:
        lagged = gen_lagged_data(metadata, data_full, target_date, lag)
        
        # Solo usar datos HASTA el target_date
        X_pred = lagged[[c for c in dfm_cols if c in lagged.columns]].copy()
        if TARGET in X_pred.columns:
            X_pred[TARGET] = np.nan
            
        for col in dfm_cols:
            if col not in X_pred.columns:
                X_pred[col] = np.nan
        X_pred = X_pred[dfm_cols]
        
        # Llenar NAs con medias del training
        for col in dfm_cols:
            X_pred[col] = X_pred[col].fillna(X_train[col].mean())
        
        # Estandarizar
        X_new_scaled = pd.DataFrame(
            scaler.transform(X_pred),
            columns=dfm_cols
        )
        
        # NUEVO: usar append() para extender el modelo con nuevos datos
        # Esto corre el Kalman filter forward correctamente
        n_train = len(X_scaled)
        n_total = len(X_new_scaled)
        
        if n_total <= n_train:
            # Los datos nuevos ya están dentro del training -- usar smoothed
            app = dfm_result.apply(X_new_scaled, refit=False)
            pred_scaled = float(app.factors.smoothed.iloc[-1] @ 
                               dfm_result.params[:N_FACTORS])
        else:
            # Hay datos fuera del training -- usar append + forecast
            new_obs = X_new_scaled.iloc[n_train:]
            extended = dfm_result.append(new_obs, refit=False)
            pred_scaled = float(extended.fittedvalues[TARGET].iloc[-1])
        
        # Rescalar
        idx = dfm_cols.index(TARGET)
        return float(pred_scaled * scaler.scale_[idx] + scaler.mean_[idx])
        
    except Exception as e:
        return np.nan

# =============================================================================
# 7. NOWCAST LOOP -- TWO WINDOWS
# =============================================================================

def run_window(window_cfg, window_label):
    print(f"\n{'='*55}\n  Window: {window_label}\n{'='*55}")

    dates_df     = get_monthly_test_dates(window=window_cfg)
    all_months   = dates_df["date"].tolist()
    pred_dict    = {lag: {} for lag in LAGS_USE}
    actuals_dict = {}

    for month in all_months:
        date_str   = str(month.date())
        actual_row = data.loc[data.date == month, TARGET]

        if actual_row.empty or actual_row.isna().all():
            continue

        actuals_dict[date_str] = float(actual_row.values[0])

        for lag in LAGS_USE:
            pred_dict[lag][date_str] = predict_dfm_monthly(
                data, metadata, date_str, lag
            )

        print(f"  {date_str}: "
              f"actual={actuals_dict[date_str]*100:+.2f}%  "
              f"lag-2={pred_dict[-2].get(date_str, np.nan)*100:+.2f}%  "
              f"lag-1={pred_dict[-1].get(date_str, np.nan)*100:+.2f}%  "
              f"lag 0={pred_dict[0].get(date_str, np.nan)*100:+.2f}%")

    # Metrics
    rows = []
    for lag in LAGS_USE:
        common = [
            d for d in actuals_dict
            if d in pred_dict[lag] and pd.notna(pred_dict[lag][d])
        ]
        if not common:
            print(f"  WARNING: no valid predictions for lag {lag}")
            continue
        a = np.array([actuals_dict[d]   for d in common])
        f = np.array([pred_dict[lag][d] for d in common])
        m = compute_metrics(a, f, label=str(lag))
        m["Vintage"] = lag
        rows.append(m)

    if not rows:
        print("  ERROR: no metrics computed -- all predictions are NaN")
        return pd.DataFrame(), pred_dict, actuals_dict

    perf = pd.DataFrame(rows)[["Vintage", "RMSE", "MAE", "R2", "n"]]
    print_performance_table(perf.round(4), f"DFM -- {window_label}")
    return perf, pred_dict, actuals_dict


print("\n>>> Running Window 1: Crisis (COVID-19)")
perf_w1, preds_w1, actuals_w1 = run_window(CONFIG["window_1"], "Crisis (COVID-19)")

print("\n>>> Running Window 2: Post-Pandemic")
perf_w2, preds_w2, actuals_w2 = run_window(CONFIG["window_2"], "Post-Pandemic Normalisation")

# =============================================================================
# 8. COMBINED PERFORMANCE TABLE
# =============================================================================

if not perf_w1.empty and not perf_w2.empty:
    perf_w1["Window"] = "Crisis"
    perf_w2["Window"] = "Post-Pandemic"
    combined = pd.concat([perf_w1, perf_w2], ignore_index=True)
    combined["Model"] = "DFM"

    print("\n-- Combined Performance --")
    print(combined[["Model", "Window", "Vintage", "RMSE", "MAE", "R2", "n"]]
          .to_string(index=False))

# =============================================================================
# 9. VISUALIZATIONS
# =============================================================================

def plot_window(preds, actuals_dict, window_label):
    if not actuals_dict:
        return
    dates   = sorted(actuals_dict.keys())
    dt      = [pd.Timestamp(d) for d in dates]
    actual  = [actuals_dict[d] * 100 for d in dates]
    pred_0  = [preds[0].get(d,  np.nan) * 100 for d in dates]
    pred_m1 = [preds[-1].get(d, np.nan) * 100 for d in dates]
    pred_m2 = [preds[-2].get(d, np.nan) * 100 for d in dates]

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(13, 9))

    ax1.plot(dt, actual,  color="black",   lw=1.8, label="Actual IVAE m-o-m")
    ax1.plot(dt, pred_0,  color="#2166ac", lw=1.2, ls="--", label="Nowcast (lag 0)")
    ax1.plot(dt, pred_m1, color="#f46d43", lw=1.0, ls=":",  label="lag -1", alpha=0.85)
    ax1.plot(dt, pred_m2, color="#abdda4", lw=1.0, ls="-.", label="lag -2", alpha=0.85)
    ax1.axhline(0, color="gray", lw=0.6, ls="--")
    ax1.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha="right")
    ax1.set_title(f"DFM | {window_label}", fontsize=12, fontweight="bold")
    ax1.set_ylabel("IVAE m-o-m (%)")
    ax1.legend(fontsize=9)
    ax1.grid(True, alpha=0.3)

    valid  = [(t, a, p) for t, a, p in zip(dt, actual, pred_0) if not np.isnan(p)]
    if valid:
        err_dt = [v[0] for v in valid]
        errors = [v[1] - v[2] for v in valid]
        colors_bar = ["#d73027" if e < 0 else "#4dac26" for e in errors]
        ax2.bar(err_dt, errors, color=colors_bar, width=20, alpha=0.85)
    ax2.axhline(0, color="black", lw=0.8)
    ax2.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha="right")
    ax2.set_title("Forecast Errors (Actual - Predicted, lag 0)", fontsize=11)
    ax2.set_ylabel("Error (pp)")
    ax2.grid(True, alpha=0.3)

    plt.suptitle(f"DFM | El Salvador IVAE | {window_label}",
                 fontsize=13, fontweight="bold")
    plt.tight_layout()
    plt.show()


plot_window(preds_w1, actuals_w1, "Crisis (COVID-19)")
plot_window(preds_w2, actuals_w2, "Post-Pandemic Normalisation")

# =============================================================================
# 10. SAVE RESULTS
# =============================================================================

def build_output(preds, actuals_dict, window_name):
    dates = sorted(actuals_dict.keys())
    return pd.DataFrame({
        "date"        : dates,
        "actual"      : [actuals_dict[d]          for d in dates],
        "pred_lag_m2" : [preds[-2].get(d, np.nan) for d in dates],
        "pred_lag_m1" : [preds[-1].get(d, np.nan) for d in dates],
        "pred_lag_0"  : [preds[0].get(d,  np.nan) for d in dates],
        "model"       : "DFM",
        "window"      : window_name,
    })

if actuals_w1 and actuals_w2:
    results = pd.concat([
        build_output(preds_w1, actuals_w1, "Crisis"),
        build_output(preds_w2, actuals_w2, "Post-Pandemic"),
    ], ignore_index=True)

    os.makedirs("outputs", exist_ok=True)
    results.to_csv("outputs/dfm_predictions.csv", index=False)
    if not perf_w1.empty and not perf_w2.empty:
        combined.to_csv("outputs/dfm_performance.csv", index=False)

    print(f"\nDFM complete.")
    print(f"Predictions : outputs/dfm_predictions.csv ({len(results)} rows)")
    print(f"Performance : outputs/dfm_performance.csv")
    print(f"\nNext: Ridge regression")
# Out:
# =======================================================
#   DFM -- Monthly IVAE Nowcasting (Python)
# =======================================================
# Target    : IVAE_TOT
# Vintages  : [-2, -1, 0]
# Factors   : 4
# Variables : 38
# Data loaded  : 237 rows x 123 variables
# Date range   : 2005-01-01 -> 2024-06-01
# Target (IVAE): 233 monthly observations
#
# Variables available : 38
# Training obs : 170
# Training end : 2019-02-01
# Variables after missing filter: 38
#
# >>> Estimating DFM...
# EM start iterations, llf=-8285.4
# EM iteration 2, llf=-8036.5, convergence criterion=0.030501
# EM iteration 3, llf=-7960.8, convergence criterion=0.0094624
# EM iteration 4, llf=-7901.9, convergence criterion=0.0074286
# EM iteration 5, llf=-7858, convergence criterion=0.0055679
# EM iteration 6, llf=-7829.6, convergence criterion=0.0036206
# EM iteration 7, llf=-7813.9, convergence criterion=0.0020086
# EM iteration 8, llf=-7804.9, convergence criterion=0.0011519
# EM iteration 9, llf=-7798.8, convergence criterion=0.0007896
# EM iteration 10, llf=-7794, convergence criterion=0.00060662
# EM iteration 11, llf=-7790.3, convergence criterion=0.00048623
# EM iteration 12, llf=-7787.2, convergence criterion=0.0003986
# EM iteration 13, llf=-7784.6, convergence criterion=0.00033372
# EM iteration 14, llf=-7782.3, convergence criterion=0.00028583
# EM iteration 15, llf=-7780.4, convergence criterion=0.00025091
# EM iteration 16, llf=-7778.6, convergence criterion=0.00022618
# EM iteration 17, llf=-7777, convergence criterion=0.00020985
# EM iteration 18, llf=-7775.4, convergence criterion=0.00020086
# EM iteration 19, llf=-7773.9, convergence criterion=0.00019882
# EM iteration 20, llf=-7772.3, convergence criterion=0.00020383
# EM iteration 21, llf=-7770.6, convergence criterion=0.00021641
# EM iteration 22, llf=-7768.8, convergence criterion=0.00023714
# EM iteration 23, llf=-7766.7, convergence criterion=0.00026598
# EM iteration 24, llf=-7764.4, convergence criterion=0.00030104
# EM iteration 25, llf=-7761.7, convergence criterion=0.00033692
# EM iteration 26, llf=-7758.9, convergence criterion=0.00036384
# EM iteration 27, llf=-7756.1, convergence criterion=0.0003702
# EM iteration 28, llf=-7753.3, convergence criterion=0.00034942
# EM iteration 29, llf=-7751, convergence criterion=0.00030614
# EM iteration 30, llf=-7749, convergence criterion=0.00025397
# EM iteration 31, llf=-7747.4, convergence criterion=0.00020586
# EM iteration 32, llf=-7746.1, convergence criterion=0.00016765
# EM iteration 33, llf=-7745, convergence criterion=0.00013915
# EM iteration 34, llf=-7744.1, convergence criterion=0.00011797
# EM iteration 35, llf=-7743.3, convergence criterion=0.00010187
# EM iteration 36, llf=-7742.6, convergence criterion=8.9301e-05
# EM iteration 37, llf=-7742, convergence criterion=7.9253e-05
# EM iteration 38, llf=-7741.5, convergence criterion=7.1062e-05
# EM iteration 39, llf=-7741, convergence criterion=6.4275e-05
# EM iteration 40, llf=-7740.5, convergence criterion=5.8571e-05
# EM iteration 41, llf=-7740.1, convergence criterion=5.3717e-05
# EM iteration 42, llf=-7739.7, convergence criterion=4.9544e-05
# EM iteration 43, llf=-7739.4, convergence criterion=4.592e-05
# EM iteration 44, llf=-7739, convergence criterion=4.2748e-05
# EM iteration 45, llf=-7738.7, convergence criterion=3.9949e-05
# EM iteration 46, llf=-7738.4, convergence criterion=3.7464e-05
# EM iteration 47, llf=-7738.2, convergence criterion=3.5244e-05
# EM iteration 48, llf=-7737.9, convergence criterion=3.325e-05
# EM iteration 49, llf=-7737.7, convergence criterion=3.145e-05
# EM iteration 50, llf=-7737.4, convergence criterion=2.9818e-05
# EM iteration 51, llf=-7737.2, convergence criterion=2.8332e-05
# EM iteration 52, llf=-7737, convergence criterion=2.6974e-05
# EM iteration 53, llf=-7736.8, convergence criterion=2.573e-05
# EM iteration 54, llf=-7736.6, convergence criterion=2.4584e-05
# EM iteration 55, llf=-7736.4, convergence criterion=2.3528e-05
# EM iteration 56, llf=-7736.3, convergence criterion=2.2551e-05
# EM iteration 57, llf=-7736.1, convergence criterion=2.1644e-05
# EM iteration 58, llf=-7735.9, convergence criterion=2.0802e-05
# EM iteration 59, llf=-7735.8, convergence criterion=2.0016e-05
# EM iteration 60, llf=-7735.6, convergence criterion=1.9283e-05
# EM iteration 61, llf=-7735.5, convergence criterion=1.8598e-05
# EM iteration 62, llf=-7735.3, convergence criterion=1.7955e-05
# EM iteration 63, llf=-7735.2, convergence criterion=1.7352e-05
# EM iteration 64, llf=-7735.1, convergence criterion=1.6785e-05
# EM iteration 65, llf=-7735, convergence criterion=1.625e-05
# EM iteration 66, llf=-7734.8, convergence criterion=1.5746e-05
# EM iteration 67, llf=-7734.7, convergence criterion=1.527e-05
# EM iteration 68, llf=-7734.6, convergence criterion=1.482e-05
# EM iteration 69, llf=-7734.5, convergence criterion=1.4393e-05
# EM iteration 70, llf=-7734.4, convergence criterion=1.3989e-05
# EM iteration 71, llf=-7734.3, convergence criterion=1.3605e-05
# EM iteration 72, llf=-7734.2, convergence criterion=1.3241e-05
# EM iteration 73, llf=-7734.1, convergence criterion=1.2894e-05
# EM iteration 74, llf=-7734, convergence criterion=1.2563e-05
# EM iteration 75, llf=-7733.9, convergence criterion=1.2248e-05
# EM iteration 76, llf=-7733.8, convergence criterion=1.1948e-05
# EM iteration 77, llf=-7733.7, convergence criterion=1.1661e-05
# EM iteration 78, llf=-7733.6, convergence criterion=1.1386e-05
# EM iteration 79, llf=-7733.5, convergence criterion=1.1124e-05
# EM iteration 80, llf=-7733.4, convergence criterion=1.0873e-05
# EM iteration 81, llf=-7733.4, convergence criterion=1.0632e-05
# EM iteration 82, llf=-7733.3, convergence criterion=1.0401e-05
# EM iteration 83, llf=-7733.2, convergence criterion=1.018e-05
# EM iteration 84, llf=-7733.1, convergence criterion=9.9673e-06
# EM iteration 85, llf=-7733, convergence criterion=9.763e-06
# EM iteration 86, llf=-7733, convergence criterion=9.5666e-06
# EM iteration 87, llf=-7732.9, convergence criterion=9.3777e-06
# EM iteration 88, llf=-7732.8, convergence criterion=9.1958e-06
# EM iteration 89, llf=-7732.8, convergence criterion=9.0206e-06
# EM iteration 90, llf=-7732.7, convergence criterion=8.8518e-06
# EM iteration 91, llf=-7732.6, convergence criterion=8.6889e-06
# EM iteration 92, llf=-7732.6, convergence criterion=8.5319e-06
# EM iteration 93, llf=-7732.5, convergence criterion=8.3802e-06
# EM iteration 94, llf=-7732.4, convergence criterion=8.2338e-06
# EM iteration 95, llf=-7732.4, convergence criterion=8.0923e-06
# EM iteration 96, llf=-7732.3, convergence criterion=7.9555e-06
# EM iteration 97, llf=-7732.2, convergence criterion=7.8232e-06
# EM iteration 98, llf=-7732.2, convergence criterion=7.6952e-06
# EM iteration 99, llf=-7732.1, convergence criterion=7.5712e-06
# EM iteration 100, llf=-7732.1, convergence criterion=7.4512e-06
# EM iteration 101, llf=-7732, convergence criterion=7.3349e-06
# EM iteration 102, llf=-7732, convergence criterion=7.2222e-06
# EM iteration 103, llf=-7731.9, convergence criterion=7.1129e-06
# EM iteration 104, llf=-7731.8, convergence criterion=7.0069e-06
# EM iteration 105, llf=-7731.8, convergence criterion=6.9041e-06
# EM iteration 106, llf=-7731.7, convergence criterion=6.8042e-06
# EM iteration 107, llf=-7731.7, convergence criterion=6.7073e-06
# EM iteration 108, llf=-7731.6, convergence criterion=6.6131e-06
# EM iteration 109, llf=-7731.6, convergence criterion=6.5215e-06
# EM iteration 110, llf=-7731.5, convergence criterion=6.4325e-06
# EM iteration 111, llf=-7731.5, convergence criterion=6.346e-06
# EM iteration 112, llf=-7731.4, convergence criterion=6.2619e-06
# EM iteration 113, llf=-7731.4, convergence criterion=6.18e-06
# EM iteration 114, llf=-7731.3, convergence criterion=6.1003e-06
# EM iteration 115, llf=-7731.3, convergence criterion=6.0227e-06
# EM iteration 116, llf=-7731.3, convergence criterion=5.9471e-06
# EM iteration 117, llf=-7731.2, convergence criterion=5.8735e-06
# EM iteration 118, llf=-7731.2, convergence criterion=5.8018e-06
# EM iteration 119, llf=-7731.1, convergence criterion=5.7319e-06
# EM iteration 120, llf=-7731.1, convergence criterion=5.6637e-06
# EM iteration 121, llf=-7731, convergence criterion=5.5972e-06
# EM iteration 122, llf=-7731, convergence criterion=5.5324e-06
# EM iteration 123, llf=-7730.9, convergence criterion=5.4692e-06
# EM iteration 124, llf=-7730.9, convergence criterion=5.4074e-06
# EM iteration 125, llf=-7730.9, convergence criterion=5.3472e-06
# EM iteration 126, llf=-7730.8, convergence criterion=5.2883e-06
# EM iteration 127, llf=-7730.8, convergence criterion=5.2309e-06
# EM iteration 128, llf=-7730.7, convergence criterion=5.1747e-06
# EM iteration 129, llf=-7730.7, convergence criterion=5.1199e-06
# EM iteration 130, llf=-7730.7, convergence criterion=5.0663e-06
# EM iteration 131, llf=-7730.6, convergence criterion=5.0139e-06
# EM iteration 132, llf=-7730.6, convergence criterion=4.9627e-06
# EM iteration 133, llf=-7730.5, convergence criterion=4.9126e-06
# EM iteration 134, llf=-7730.5, convergence criterion=4.8636e-06
# EM iteration 135, llf=-7730.5, convergence criterion=4.8157e-06
# EM iteration 136, llf=-7730.4, convergence criterion=4.7688e-06
# EM iteration 137, llf=-7730.4, convergence criterion=4.7229e-06
# EM iteration 138, llf=-7730.4, convergence criterion=4.678e-06
# EM iteration 139, llf=-7730.3, convergence criterion=4.634e-06
# EM iteration 140, llf=-7730.3, convergence criterion=4.591e-06
# EM iteration 141, llf=-7730.3, convergence criterion=4.5488e-06
# EM iteration 142, llf=-7730.2, convergence criterion=4.5075e-06
# EM iteration 143, llf=-7730.2, convergence criterion=4.4671e-06
# EM iteration 144, llf=-7730.2, convergence criterion=4.4274e-06
# EM iteration 145, llf=-7730.1, convergence criterion=4.3886e-06
# EM iteration 146, llf=-7730.1, convergence criterion=4.3505e-06
# EM iteration 147, llf=-7730.1, convergence criterion=4.3132e-06
# EM iteration 148, llf=-7730, convergence criterion=4.2766e-06
# EM iteration 149, llf=-7730, convergence criterion=4.2407e-06
# EM iteration 150, llf=-7730, convergence criterion=4.2055e-06
# EM iteration 151, llf=-7729.9, convergence criterion=4.1709e-06
# EM iteration 152, llf=-7729.9, convergence criterion=4.137e-06
# EM iteration 153, llf=-7729.9, convergence criterion=4.1038e-06
# EM iteration 154, llf=-7729.8, convergence criterion=4.0712e-06
# EM iteration 155, llf=-7729.8, convergence criterion=4.0392e-06
# EM iteration 156, llf=-7729.8, convergence criterion=4.0077e-06
# EM iteration 157, llf=-7729.7, convergence criterion=3.9769e-06
# EM iteration 158, llf=-7729.7, convergence criterion=3.9466e-06
# EM iteration 159, llf=-7729.7, convergence criterion=3.9168e-06
# EM iteration 160, llf=-7729.6, convergence criterion=3.8876e-06
# EM iteration 161, llf=-7729.6, convergence criterion=3.8589e-06
# EM iteration 162, llf=-7729.6, convergence criterion=3.8307e-06
# EM iteration 163, llf=-7729.6, convergence criterion=3.803e-06
# EM iteration 164, llf=-7729.5, convergence criterion=3.7758e-06
# EM iteration 165, llf=-7729.5, convergence criterion=3.749e-06
# EM iteration 166, llf=-7729.5, convergence criterion=3.7227e-06
# EM iteration 167, llf=-7729.4, convergence criterion=3.6969e-06
# EM iteration 168, llf=-7729.4, convergence criterion=3.6715e-06
# EM iteration 169, llf=-7729.4, convergence criterion=3.6465e-06
# EM iteration 170, llf=-7729.4, convergence criterion=3.6219e-06
# EM iteration 171, llf=-7729.3, convergence criterion=3.5977e-06
# EM iteration 172, llf=-7729.3, convergence criterion=3.574e-06
# EM iteration 173, llf=-7729.3, convergence criterion=3.5506e-06
# EM iteration 174, llf=-7729.2, convergence criterion=3.5276e-06
# EM iteration 175, llf=-7729.2, convergence criterion=3.505e-06
# EM iteration 176, llf=-7729.2, convergence criterion=3.4827e-06
# EM iteration 177, llf=-7729.2, convergence criterion=3.4608e-06
# EM iteration 178, llf=-7729.1, convergence criterion=3.4393e-06
# EM iteration 179, llf=-7729.1, convergence criterion=3.4181e-06
# EM iteration 180, llf=-7729.1, convergence criterion=3.3972e-06
# EM iteration 181, llf=-7729.1, convergence criterion=3.3766e-06
# EM iteration 182, llf=-7729, convergence criterion=3.3564e-06
# EM iteration 183, llf=-7729, convergence criterion=3.3364e-06
# EM iteration 184, llf=-7729, convergence criterion=3.3168e-06
# EM iteration 185, llf=-7729, convergence criterion=3.2975e-06
# EM iteration 186, llf=-7728.9, convergence criterion=3.2785e-06
# EM iteration 187, llf=-7728.9, convergence criterion=3.2597e-06
# EM iteration 188, llf=-7728.9, convergence criterion=3.2412e-06
# EM iteration 189, llf=-7728.9, convergence criterion=3.223e-06
# EM iteration 190, llf=-7728.8, convergence criterion=3.2051e-06
# EM iteration 191, llf=-7728.8, convergence criterion=3.1875e-06
# EM iteration 192, llf=-7728.8, convergence criterion=3.1701e-06
# EM iteration 193, llf=-7728.8, convergence criterion=3.1529e-06
# EM iteration 194, llf=-7728.7, convergence criterion=3.136e-06
# EM iteration 195, llf=-7728.7, convergence criterion=3.1194e-06
# EM iteration 196, llf=-7728.7, convergence criterion=3.1029e-06
# EM iteration 197, llf=-7728.7, convergence criterion=3.0867e-06
# EM iteration 198, llf=-7728.6, convergence criterion=3.0708e-06
# EM iteration 199, llf=-7728.6, convergence criterion=3.0551e-06
# EM iteration 200, llf=-7728.6, convergence criterion=3.0395e-06
# EM reached maximum number of iterations (200), without achieving convergence: llf=-7728.6, convergence criterion=3.0395e-06 (while specified tolerance was 1e-06)
# Log-likelihood : -7728.5671
#
# >>> Diagnosing prediction method...
#   Method apply+fittedvalues: 0.209%
#   Method smoothed_state FAILED: 'DynamicFactorMQResults' object has no attribute 'loadings'
#   Using method: apply_fitted
#   Actual IVAE 2019-06: 0.970%
#
# Sanity check 2019-06-01:
#   Actual   : 0.970%
#   Predicted: 0.209%
#
# >>> Running Window 1: Crisis (COVID-19)
#
# =======================================================
#   Window: Crisis (COVID-19)
# =======================================================
# Window  : Crisis (COVID-19)
# Months  : 28 (10 quarters)
# Period  : 2019-03-01 -> 2021-06-01
#   2019-03-01: actual=+0.33%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-04-01: actual=+0.86%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-05-01: actual=-1.29%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-06-01: actual=+0.97%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-07-01: actual=+0.05%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-08-01: actual=+0.14%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-09-01: actual=+0.39%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-10-01: actual=-0.35%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-11-01: actual=+1.02%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2019-12-01: actual=+0.00%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-01-01: actual=-0.93%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-02-01: actual=+0.50%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-03-01: actual=-7.85%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-04-01: actual=-13.22%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-05-01: actual=-3.38%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-06-01: actual=+6.94%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-07-01: actual=+5.41%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-08-01: actual=+5.10%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-09-01: actual=+4.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-10-01: actual=+0.78%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-11-01: actual=+0.49%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2020-12-01: actual=+1.62%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-01-01: actual=+0.45%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-02-01: actual=+0.61%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-03-01: actual=+0.36%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-04-01: actual=+0.74%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-05-01: actual=-0.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-06-01: actual=+1.08%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#
# ==========================================================
#   DFM -- Crisis (COVID-19) -- Performance by Vintage
# ==========================================================
#  Vintage   RMSE    MAE      R2  n
#       -2 0.0368 0.0204 -0.0001 28
#       -1 0.0368 0.0204 -0.0001 28
#        0 0.0368 0.0204 -0.0002 28
#
# Vintage key:
#   -2 -> Month 1 of quarter  (least information)
#   -1 -> Month 2 of quarter
#    0 -> Month 3 / quarter-end  (most information)
#
# >>> Running Window 2: Post-Pandemic
#
# =======================================================
#   Window: Post-Pandemic Normalisation
# =======================================================
# Window  : Post-Pandemic Normalisation
# Months  : 34 (12 quarters)
# Period  : 2021-09-01 -> 2024-06-01
#   2021-09-01: actual=+0.50%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-10-01: actual=+0.18%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-11-01: actual=+0.31%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2021-12-01: actual=-0.75%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-01-01: actual=+0.68%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-02-01: actual=+0.36%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-03-01: actual=+0.54%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-04-01: actual=-0.48%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-05-01: actual=+1.70%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-06-01: actual=-0.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-07-01: actual=+0.30%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-08-01: actual=+0.81%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-09-01: actual=-0.38%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-10-01: actual=+0.82%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-11-01: actual=-0.96%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2022-12-01: actual=-0.34%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-01-01: actual=+1.45%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-02-01: actual=-0.49%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-03-01: actual=+1.45%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-04-01: actual=+0.06%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-05-01: actual=+1.27%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-06-01: actual=+0.39%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-07-01: actual=-0.52%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-08-01: actual=-1.17%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-09-01: actual=+0.15%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-10-01: actual=-0.13%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-11-01: actual=+3.15%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2023-12-01: actual=-1.43%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2024-01-01: actual=+1.84%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2024-02-01: actual=-1.96%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2024-03-01: actual=-0.06%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2024-04-01: actual=+0.35%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2024-05-01: actual=+1.46%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#   2024-06-01: actual=-2.61%  lag-2=+0.21%  lag-1=+0.21%  lag 0=+0.21%
#
# ====================================================================
#   DFM -- Post-Pandemic Normalisation -- Performance by Vintage
# ====================================================================
#  Vintage   RMSE    MAE      R2  n
#       -2 0.0112 0.0084 -0.0005 34
#       -1 0.0112 0.0084 -0.0005 34
#        0 0.0112 0.0084 -0.0002 34
#
# Vintage key:
#   -2 -> Month 1 of quarter  (least information)
#   -1 -> Month 2 of quarter
#    0 -> Month 3 / quarter-end  (most information)
#
# -- Combined Performance --
# Model        Window  Vintage     RMSE      MAE        R2  n
#   DFM        Crisis       -2 0.036832 0.020406 -0.000101 28
#   DFM        Crisis       -1 0.036832 0.020406 -0.000100 28
#   DFM        Crisis        0 0.036833 0.020407 -0.000164 28
#   DFM Post-Pandemic       -2 0.011195 0.008371 -0.000459 34
#   DFM Post-Pandemic       -1 0.011195 0.008371 -0.000457 34
#   DFM Post-Pandemic        0 0.011193 0.008370 -0.000208 34
# DFM complete.
# Predictions : outputs/dfm_predictions.csv (62 rows)
# Performance : outputs/dfm_performance.csv
#
# Next: Ridge regression

# %%
# Diagnóstico -- qué atributos tiene el resultado
app = dfm_result.apply(test_X, refit=False)
print("Atributos disponibles:")
attrs = [a for a in dir(app) if not a.startswith('_')]
for a in attrs:
    print(f"  {a}")
# Out:
# Atributos disponibles:
#   aic
#   aicc
#   append
#   apply
#   bic
#   bse
#   coefficients_of_determination
#   conf_int
#   cov_kwds
#   cov_params
#   cov_params_approx
#   cov_params_default
#   cov_params_oim
#   cov_params_opg
#   cov_params_robust
#   cov_params_robust_approx
#   cov_params_robust_oim
#   cov_type
#   data
#   df_model
#   df_resid
#   extend
#   f_test
#   factors
#   filter_results
#   filtered_state
#   filtered_state_cov
#   fittedvalues
#   fixed_params
#   forecast
#   forecasts
#   forecasts_error
#   forecasts_error_cov
#   forecasts_error_diffuse_cov
#   get_coefficients_of_determination
#   get_forecast
#   get_prediction
#   get_smoothed_decomposition
#   hqic
#   impulse_responses
#   info_criteria
#   initialize
#   k_constant
#   k_diffuse_states
#   llf
#   llf_obs
#   load
#   loglikelihood_burn
#   mae
#   model
#   mse
#   news
#   nobs
#   nobs_diffuse
#   nobs_effective
#   normalized_cov_params
#   param_names
#   params
#   plot_coefficients_of_determination
#   plot_diagnostics
#   predict
#   predicted_diffuse_state_cov
#   predicted_state
#   predicted_state_cov
#   pvalues
#   remove_data
#   resid
#   save
#   scale
#   scaled_smoothed_estimator
#   scaled_smoothed_estimator_cov
#   simulate
#   smoothed_measurement_disturbance
#   smoothed_measurement_disturbance_cov
#   smoothed_state
#   smoothed_state_autocov
#   smoothed_state_cov
#   smoothed_state_disturbance
#   smoothed_state_disturbance_cov
#   smoother_results
#   smoothing_error
#   sse
#   standardized_forecasts_error
#   states
#   summary
#   t_test
#   t_test_pairwise
#   test_heteroskedasticity
#   test_normality
#   test_serial_correlation
#   tvalues
#   use_t
#   wald_test
#   wald_test_terms
#   zvalues

# %%
# Diagnóstico 2 -- explorar factors y predict
app = dfm_result.apply(test_X, refit=False)

# Opcion 1: factors attribute
print("=== factors ===")
try:
    f = app.factors
    print(type(f))
    print(dir(f))
except Exception as e:
    print(f"FAILED: {e}")

# Opcion 2: smoothed_state
print("\n=== smoothed_state ===")
try:
    ss = app.smoothed_state
    print("shape:", ss.shape)
    print("last col:", ss[:, -1])
except Exception as e:
    print(f"FAILED: {e}")

# Opcion 3: predict
print("\n=== predict ===")
try:
    pred = app.predict()
    print(type(pred))
    if hasattr(pred, 'columns'):
        print("columns:", pred.columns.tolist()[:5])
        print("last row TARGET:", pred[TARGET].iloc[-1] if TARGET in pred.columns else "not found")
    else:
        print(pred[-5:])
except Exception as e:
    print(f"FAILED: {e}")

# Opcion 4: states
print("\n=== states ===")
try:
    st = app.states
    print(type(st))
    print(dir(st))
except Exception as e:
    print(f"FAILED: {e}")

# Opcion 5: forecasts
print("\n=== forecasts ===")
try:
    fc = app.forecasts
    print("shape:", fc.shape)
    print("last row:", fc[:, -1])
except Exception as e:
    print(f"FAILED: {e}")
# Out:
# === factors ===
# <class 'statsmodels.tools.tools.Bunch'>
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'clear', 'copy', 'filtered', 'filtered_cov', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'smoothed', 'smoothed_cov', 'update', 'values']
#
# === smoothed_state ===
# shape: (4, 174)
# last col: [-3.21353746e-05  2.39166930e-05 -2.69123124e-06 -6.22623698e-05]
#
# === predict ===
# <class 'pandas.DataFrame'>
# columns: ['IVAE_TOT', 'IVAE_AG', 'IVAE_IN', 'IVAE_CO', 'IVAE_CT']
# last row TARGET: -0.00019487647344299772
#
# === states ===
# <class 'types.SimpleNamespace'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'filtered', 'filtered_cov', 'predicted', 'predicted_cov', 'smoothed', 'smoothed_cov']
#
# === forecasts ===
# shape: (38, 174)
# last row: [-1.94302462e-04  2.66552975e-04 -6.41140349e-05 -2.80097375e-05
#  -3.21290669e-04 -1.04956941e-04 -6.41140349e-05 -1.51261264e-03
#  -1.89222126e-03 -5.80343103e-04 -6.20072568e-04 -7.76871851e-05
#   2.90256580e-04 -1.16730271e-03  2.71473097e-05 -4.33497614e-04
#  -7.35122717e-04 -6.32804188e-04 -2.80106679e-04  3.70585335e-04
#   2.29751706e-04  9.66976382e-05 -1.14873551e-04 -1.00435462e-03
#  -1.00609293e-04  8.61528969e-04  4.35121751e-04  2.91300177e-05
#  -3.72937839e-04  2.61289891e-04  1.34814718e-05 -3.39002018e-05
#  -2.22834772e-04 -1.86754293e-04 -1.71364525e-04  1.61459902e-04
#   1.66189519e-04 -2.60073495e-05]

# %%
# Diagnóstico 3 -- verificar rescaling
app = dfm_result.apply(test_X, refit=False)

# Valor en espacio estandarizado
pred_scaled = float(app.predict()[TARGET].iloc[-1])
print(f"Pred scaled   : {pred_scaled:.6f}")

# Parámetros del scaler para IVAE_TOT
idx = dfm_cols.index(TARGET)
mean_ivae  = scaler.mean_[idx]
scale_ivae = scaler.scale_[idx]
print(f"Training mean : {mean_ivae:.6f}  ({mean_ivae*100:.3f}%)")
print(f"Training std  : {scale_ivae:.6f}  ({scale_ivae*100:.3f}%)")

# Rescaling
pred_original = pred_scaled * scale_ivae + mean_ivae
print(f"Pred original : {pred_original:.6f}  ({pred_original*100:.3f}%)")

# Comparar con fittedvalues
fitted_scaled = float(app.fittedvalues[TARGET].iloc[-1])
fitted_original = fitted_scaled * scale_ivae + mean_ivae
print(f"\nFitted scaled   : {fitted_scaled:.6f}")
print(f"Fitted original : {fitted_original:.6f}  ({fitted_original*100:.3f}%)")

# Verificar: predict vs fittedvalues son lo mismo?
print(f"\nSon iguales: {abs(pred_scaled - fitted_scaled) < 1e-10}")

# Ver factors.smoothed para la ultima observacion
factors_last = app.factors.smoothed.iloc[-1]
print(f"\nFactors last: {factors_last.values}")
print(f"Factors smoothed shape: {app.factors.smoothed.shape}")
print(f"Factors smoothed last 3 rows:\n{app.factors.smoothed.tail(3)}")
# Out:
# Pred scaled   : -0.000195
# Training mean : 0.002096  (0.210%)
# Training std  : 0.016581  (1.658%)
# Pred original : 0.002093  (0.209%)
#
# Fitted scaled   : -0.000194
# Fitted original : 0.002093  (0.209%)
#
# Son iguales: False
#
# Factors last: [-3.21353746e-05  2.39166930e-05 -2.69123124e-06 -6.22623698e-05]
# Factors smoothed shape: (174, 4)
# Factors smoothed last 3 rows:
#             0         1         2         3
# 171 -2.505982  0.014544 -0.109074 -0.169617
# 172  0.006403 -0.002498 -0.000495  0.005920
# 173 -0.000032  0.000024 -0.000003 -0.000062
